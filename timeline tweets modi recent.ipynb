# %%
import tweepy
import json
import pandas as pd

# %%
consumer_key = "consumer_key"
consumer_secret = "consumer_secret"
access_token = "access_token"
access_token_secret = "access_token_secret"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
results=[]

timeline = tweepy.Cursor(api.user_timeline, screen_name='@narendramodi', tweet_mode="extended").items(3200)

for status in timeline:
    data = (
    status.user.id,
    status.user.screen_name,
    status.user.name,
    status.full_text,
    status.created_at,
    status.lang)
    results.append(data)

cols = "user_id screen_name name text date lang".split()
df = pd.DataFrame(results, columns=cols)

# %%
df
# Out:
#        user_id   screen_name           name  \
# 0     18839785  narendramodi  Narendra Modi
# 1     18839785  narendramodi  Narendra Modi
# 2     18839785  narendramodi  Narendra Modi
# 3     18839785  narendramodi  Narendra Modi
# 4     18839785  narendramodi  Narendra Modi
# ...        ...           ...            ...
# 1415  18839785  narendramodi  Narendra Modi
# 1416  18839785  narendramodi  Narendra Modi
# 1417  18839785  narendramodi  Narendra Modi
# 1418  18839785  narendramodi  Narendra Modi
# 1419  18839785  narendramodi  Narendra Modi
#
#                                                    text                date  \
# 0     2 मई के बाद डबल इंजन की सरकार हावड़ा सहित पूरे... 2021-04-06 15:52:00
# 1     सोनार बांग्ला आचरण से बनेगा, साफ नीयत से बनेगा... 2021-04-06 15:51:42
# 2     दीदी, कितना विश्वास किया था बंगाल के लोगों ने ... 2021-04-06 15:51:26
# 3     हावड़ा सहित पूरे पश्चिम बंगाल का डेवलपमेंट यहा... 2021-04-06 15:51:11
# 4     मुझे कुछ लोगों ने बताया कि दीदी आजकल लोगों को ... 2021-04-06 11:23:48
# ...                                                 ...                 ...
# 1415  Demonetisation has helped reduce black money, ... 2020-11-08 08:37:32
# 1416  Went to Advani Ji’s residence to wish him on h... 2020-11-08 07:18:17
# 1417  Next generation transport and infrastructure f... 2020-11-08 05:52:43
# 1418  भाजपा को जन-जन तक पहुंचाने के साथ देश के विकास... 2020-11-08 02:45:22
# 1419  Heartiest congratulations @KamalaHarris! Your ... 2020-11-07 18:38:42
#
#      lang
# 0      hi
# 1      hi
# 2      hi
# 3      hi
# 4      hi
# ...   ...
# 1415   en
# 1416   en
# 1417   en
# 1418   hi
# 1419   en
#
# [1420 rows x 6 columns]

# %%
df.drop(columns=['user_id','name'],axis=1 , inplace=True)

# %%
df
# Out:
#        screen_name                                               text  \
# 0     narendramodi  2 मई के बाद डबल इंजन की सरकार हावड़ा सहित पूरे...
# 1     narendramodi  सोनार बांग्ला आचरण से बनेगा, साफ नीयत से बनेगा...
# 2     narendramodi  दीदी, कितना विश्वास किया था बंगाल के लोगों ने ...
# 3     narendramodi  हावड़ा सहित पूरे पश्चिम बंगाल का डेवलपमेंट यहा...
# 4     narendramodi  मुझे कुछ लोगों ने बताया कि दीदी आजकल लोगों को ...
# ...            ...                                                ...
# 1415  narendramodi  Demonetisation has helped reduce black money, ...
# 1416  narendramodi  Went to Advani Ji’s residence to wish him on h...
# 1417  narendramodi  Next generation transport and infrastructure f...
# 1418  narendramodi  भाजपा को जन-जन तक पहुंचाने के साथ देश के विकास...
# 1419  narendramodi  Heartiest congratulations @KamalaHarris! Your ...
#
#                     date lang
# 0    2021-04-06 15:52:00   hi
# 1    2021-04-06 15:51:42   hi
# 2    2021-04-06 15:51:26   hi
# 3    2021-04-06 15:51:11   hi
# 4    2021-04-06 11:23:48   hi
# ...                  ...  ...
# 1415 2020-11-08 08:37:32   en
# 1416 2020-11-08 07:18:17   en
# 1417 2020-11-08 05:52:43   en
# 1418 2020-11-08 02:45:22   hi
# 1419 2020-11-07 18:38:42   en
#
# [1420 rows x 4 columns]

# %%
df.to_csv('tweets_modi_timelinetweetrecent.txt' , sep=',' , encoding = 'utf-8')

# %%
df2=pd.read_csv('tweets_modi_timelinetweetrecent.txt' , error_bad_lines=False)
df2
# Out:
# b'Skipping line 5: expected 5 fields, saw 7\nSkipping line 8: expected 5 fields, saw 7\nSkipping line 16: expected 5 fields, saw 9\nSkipping line 91: expected 5 fields, saw 6\nSkipping line 133: expected 5 fields, saw 6\nSkipping line 137: expected 5 fields, saw 7\nSkipping line 153: expected 5 fields, saw 7\nSkipping line 172: expected 5 fields, saw 6\nSkipping line 211: expected 5 fields, saw 7\nSkipping line 263: expected 5 fields, saw 7\nSkipping line 560: expected 5 fields, saw 6\nSkipping line 562: expected 5 fields, saw 6\nSkipping line 620: expected 5 fields, saw 6\nSkipping line 648: expected 5 fields, saw 6\nSkipping line 667: expected 5 fields, saw 6\nSkipping line 688: expected 5 fields, saw 6\nSkipping line 698: expected 5 fields, saw 7\nSkipping line 702: expected 5 fields, saw 6\nSkipping line 795: expected 5 fields, saw 7\nSkipping line 801: expected 5 fields, saw 6\nSkipping line 821: expected 5 fields, saw 7\nSkipping line 823: expected 5 fields, saw 7\nSkipping line 830: expected 5 fields, saw 6\nSkipping line 844: expected 5 fields, saw 7\n'
#      Unnamed: 0   screen_name  \
# 0            25  narendramodi
# 1            26  narendramodi
# 2            27  narendramodi
# 3            29  narendramodi
# 4            30  narendramodi
# ..          ...           ...
# 896         960  narendramodi
# 897         961  narendramodi
# 898         962  narendramodi
# 899         963  narendramodi
# 900         964  narendramodi
#
#                                                   text                 date  \
# 0    Happy to have met you and the brilliant Nambi ...  2021-04-05 13:27:50
# 1    The strength and faith of the people of the co...  2021-04-05 13:25:25
# 2    A new format, several interesting questions on...  2021-04-05 03:28:47
# 3    My best wishes to President Alberto Fernández ...  2021-04-04 14:35:13
# 4    Reviewed the COVID-19 and vaccination related ...  2021-04-04 12:09:12
# ..                                                 ...                  ...
# 896  Starting today, the work of 6 light house proj...  2021-01-01 11:40:05
# 897  Birthday wishes to Manipur’s CM Shri  @NBirenS...  2021-01-01 11:39:00
# 898  Leveraging latest technologies to ensure #Hous...  2021-01-01 06:35:10
# 899  The The Light House Projects (LHPs) will showc...  2021-01-01 04:51:10
# 900  I would specially call upon my young friends, ...  2021-01-01 04:51:10
#
#     langs
# 0      en
# 1      hi
# 2      en
# 3      en
# 4      en
# ..    ...
# 896    hi
# 897    en
# 898    en
# 899    en
# 900    en
#
# [901 rows x 5 columns]

# %%
df2.drop(columns=['Unnamed: 0','langs'],axis=1 , inplace=True)

# %%
df2
# Out:
#       screen_name                                               text  \
# 0    narendramodi  Happy to have met you and the brilliant Nambi ...
# 1    narendramodi  The strength and faith of the people of the co...
# 2    narendramodi  A new format, several interesting questions on...
# 3    narendramodi  My best wishes to President Alberto Fernández ...
# 4    narendramodi  Reviewed the COVID-19 and vaccination related ...
# ..            ...                                                ...
# 896  narendramodi  Starting today, the work of 6 light house proj...
# 897  narendramodi  Birthday wishes to Manipur’s CM Shri  @NBirenS...
# 898  narendramodi  Leveraging latest technologies to ensure #Hous...
# 899  narendramodi  The The Light House Projects (LHPs) will showc...
# 900  narendramodi  I would specially call upon my young friends, ...
#
#                     date
# 0    2021-04-05 13:27:50
# 1    2021-04-05 13:25:25
# 2    2021-04-05 03:28:47
# 3    2021-04-04 14:35:13
# 4    2021-04-04 12:09:12
# ..                   ...
# 896  2021-01-01 11:40:05
# 897  2021-01-01 11:39:00
# 898  2021-01-01 06:35:10
# 899  2021-01-01 04:51:10
# 900  2021-01-01 04:51:10
#
# [901 rows x 3 columns]

# %%
df2.to_csv('tweets_modi_timelinetweetrecent.csv' , sep=',')

# %%
df2=pd.read_csv('tweets_modi_timelinetweetrecent.csv' )
df2
# Out:
#      Unnamed: 0   screen_name  \
# 0             0  narendramodi
# 1             1  narendramodi
# 2             2  narendramodi
# 3             3  narendramodi
# 4             4  narendramodi
# ..          ...           ...
# 896         896  narendramodi
# 897         897  narendramodi
# 898         898  narendramodi
# 899         899  narendramodi
# 900         900  narendramodi
#
#                                                   text                 date
# 0    Happy to have met you and the brilliant Nambi ...  2021-04-05 13:27:50
# 1    The strength and faith of the people of the co...  2021-04-05 13:25:25
# 2    A new format, several interesting questions on...  2021-04-05 03:28:47
# 3    My best wishes to President Alberto Fernández ...  2021-04-04 14:35:13
# 4    Reviewed the COVID-19 and vaccination related ...  2021-04-04 12:09:12
# ..                                                 ...                  ...
# 896  Starting today, the work of 6 light house proj...  2021-01-01 11:40:05
# 897  Birthday wishes to Manipur’s CM Shri  @NBirenS...  2021-01-01 11:39:00
# 898  Leveraging latest technologies to ensure #Hous...  2021-01-01 06:35:10
# 899  The The Light House Projects (LHPs) will showc...  2021-01-01 04:51:10
# 900  I would specially call upon my young friends, ...  2021-01-01 04:51:10
#
# [901 rows x 4 columns]

# %%
df2.drop(columns=['Unnamed: 0'],axis=1 , inplace=True)

# %%
df2
# Out:
#       screen_name                                               text  \
# 0    narendramodi  Happy to have met you and the brilliant Nambi ...
# 1    narendramodi  The strength and faith of the people of the co...
# 2    narendramodi  A new format, several interesting questions on...
# 3    narendramodi  My best wishes to President Alberto Fernández ...
# 4    narendramodi  Reviewed the COVID-19 and vaccination related ...
# ..            ...                                                ...
# 896  narendramodi  Starting today, the work of 6 light house proj...
# 897  narendramodi  Birthday wishes to Manipur’s CM Shri  @NBirenS...
# 898  narendramodi  Leveraging latest technologies to ensure #Hous...
# 899  narendramodi  The The Light House Projects (LHPs) will showc...
# 900  narendramodi  I would specially call upon my young friends, ...
#
#                     date
# 0    2021-04-05 13:27:50
# 1    2021-04-05 13:25:25
# 2    2021-04-05 03:28:47
# 3    2021-04-04 14:35:13
# 4    2021-04-04 12:09:12
# ..                   ...
# 896  2021-01-01 11:40:05
# 897  2021-01-01 11:39:00
# 898  2021-01-01 06:35:10
# 899  2021-01-01 04:51:10
# 900  2021-01-01 04:51:10
#
# [901 rows x 3 columns]

# %%
import re


def cleanTxt(txt):
    
    txt = re.sub(r'@[A-Za-z0-9_:]+', '' , txt)
    
    txt = re.sub(r'#', '' , txt)
    
    txt = re.sub(r'RT[\s]+','',txt)
    
    txt = re.sub(r'https?:\/\/\S+','',txt)
    
    txt = re.sub(r'\d+', '', txt)
    return txt

df2['text'] = df2["text"].apply(cleanTxt)

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#Removing punctation
df2['text'] = df2['text'].str.translate(str.maketrans(" ", " ", string.punctuation))

# %%
df2
# Out:
#       screen_name                                               text  \
# 0    narendramodi  Happy to have met you and the brilliant Nambi ...
# 1    narendramodi  The strength and faith of the people of the co...
# 2    narendramodi  A new format several interesting questions on ...
# 3    narendramodi  My best wishes to President Alberto Fernández ...
# 4    narendramodi  Reviewed the COVID and vaccination related sit...
# ..            ...                                                ...
# 896  narendramodi  Starting today the work of  light house projec...
# 897  narendramodi  Birthday wishes to Manipur’s CM Shri   Ji His ...
# 898  narendramodi  Leveraging latest technologies to ensure Housi...
# 899  narendramodi  The The Light House Projects LHPs will showcas...
# 900  narendramodi  I would specially call upon my young friends e...
#
#                     date
# 0    2021-04-05 13:27:50
# 1    2021-04-05 13:25:25
# 2    2021-04-05 03:28:47
# 3    2021-04-04 14:35:13
# 4    2021-04-04 12:09:12
# ..                   ...
# 896  2021-01-01 11:40:05
# 897  2021-01-01 11:39:00
# 898  2021-01-01 06:35:10
# 899  2021-01-01 04:51:10
# 900  2021-01-01 04:51:10
#
# [901 rows x 3 columns]

# %%
#FOR  SENTIMENT LABELLING WE HAVE TO IMPORT  NLKT 


import nltk
nltk.download('vader_lexicon')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yashw\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def print_sentiment_scores(tweets):
    vadersenti = analyser.polarity_scores(tweets)
    return pd.Series([vadersenti['pos'], vadersenti['neg'], vadersenti['neu'], vadersenti['compound']])

# %%
df2[['vadersenti_pos', 'vadersenti_neg', 'vadersenti_neu', 'vadersenti_compound']]  = df2['text'].apply(print_sentiment_scores)

# %%
df2['senti'] = 'neutral'
df2.loc[df2['vadersenti_compound'] > 0 , 'senti'] = 'positive'
df2.loc[df2['vadersenti_compound'] < 0,'senti'] = 'negative'

df2['vader_possentiment'] = 0
df2.loc[df2['vadersenti_compound'] > 0 , 'vader_possentiment'] = 1

df2['vader_negsentiment'] = 0
df2.loc[df2['vadersenti_compound'] < 0 , 'vader_negsentiment'] = 1

df2['vader_neusentiment'] = 0
df2.loc[(df2['vadersenti_compound'] <0) & (df2['vadersenti_compound'] >=0) , 'vader_neusentiment'] = 1

# %%
df2
# Out:
#       screen_name                                               text  \
# 0    narendramodi  Happy to have met you and the brilliant Nambi ...
# 1    narendramodi  The strength and faith of the people of the co...
# 2    narendramodi  A new format several interesting questions on ...
# 3    narendramodi  My best wishes to President Alberto Fernández ...
# 4    narendramodi  Reviewed the COVID and vaccination related sit...
# ..            ...                                                ...
# 896  narendramodi  Starting today the work of  light house projec...
# 897  narendramodi  Birthday wishes to Manipur’s CM Shri   Ji His ...
# 898  narendramodi  Leveraging latest technologies to ensure Housi...
# 899  narendramodi  The The Light House Projects LHPs will showcas...
# 900  narendramodi  I would specially call upon my young friends e...
#
#                     date  vadersenti_pos  vadersenti_neg  vadersenti_neu  \
# 0    2021-04-05 13:27:50           0.246           0.000           0.754
# 1    2021-04-05 13:25:25           0.190           0.000           0.810
# 2    2021-04-05 03:28:47           0.169           0.000           0.831
# 3    2021-04-04 14:35:13           0.309           0.000           0.691
# 4    2021-04-04 12:09:12           0.139           0.065           0.796
# ..                   ...             ...             ...             ...
# 896  2021-01-01 11:40:05           0.104           0.106           0.790
# 897  2021-01-01 11:39:00           0.459           0.000           0.541
# 898  2021-01-01 06:35:10           0.342           0.000           0.658
# 899  2021-01-01 04:51:10           0.173           0.000           0.827
# 900  2021-01-01 04:51:10           0.206           0.000           0.794
#
#      vadersenti_compound     senti  vader_possentiment  vader_negsentiment  \
# 0                 0.9246  positive                   1                   0
# 1                 0.8402  positive                   1                   0
# 2                 0.7269  positive                   1                   0
# 3                 0.7003  positive                   1                   0
# 4                 0.4588  positive                   1                   0
# ..                   ...       ...                 ...                 ...
# 896              -0.0164  negative                   0                   1
# 897               0.9337  positive                   1                   0
# 898               0.3818  positive                   1                   0
# 899               0.8074  positive                   1                   0
# 900               0.8625  positive                   1                   0
#
#      vader_neusentiment
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 896                   0
# 897                   0
# 898                   0
# 899                   0
# 900                   0
#
# [901 rows x 11 columns]

# %%
ptweets = df2[df2.senti == 'positive'] 
ptweets = ptweets['text']

round(   (ptweets.shape[0]/ df2.shape[0])*100 , 1)
# Out:
# 76.4

# %%
ptweets = df2[df2.senti == 'negative'] 
ptweets = ptweets['text']

round(   (ptweets.shape[0]/ df2.shape[0])*100 , 1)
# Out:
# 6.0

# %%
import matplotlib.pyplot as plt
df2['senti'].value_counts()

plt.title('sentiment analysis')
plt.xlabel('sentiment')
plt.ylabel('counts')
df2['senti'].value_counts().plot(kind='bar')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (3,3))
wedgeprops = {"linewidth": 4, 'width':1, "edgecolor":"k"} # Width = 1
# Data to plot
labels = 'Positive', 'Negative', 'Neutral'
sizes = [76.4,6.0,17.6]
colors = ['gold', 'yellowgreen', '#ff9999']
explode = (0.1, 0.1, 0.1)  # explode 1st slice
radius = 3.2
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df2=df2.drop(['screen_name','vadersenti_pos','vadersenti_neg','vadersenti_neu','vader_possentiment','vader_negsentiment','vader_neusentiment'],axis=1)

# %%
df2
# Out:
#                                                   text                 date  \
# 0    Happy to have met you and the brilliant Nambi ...  2021-04-05 13:27:50
# 1    The strength and faith of the people of the co...  2021-04-05 13:25:25
# 2    A new format several interesting questions on ...  2021-04-05 03:28:47
# 3    My best wishes to President Alberto Fernández ...  2021-04-04 14:35:13
# 4    Reviewed the COVID and vaccination related sit...  2021-04-04 12:09:12
# ..                                                 ...                  ...
# 896  Starting today the work of  light house projec...  2021-01-01 11:40:05
# 897  Birthday wishes to Manipur’s CM Shri   Ji His ...  2021-01-01 11:39:00
# 898  Leveraging latest technologies to ensure Housi...  2021-01-01 06:35:10
# 899  The The Light House Projects LHPs will showcas...  2021-01-01 04:51:10
# 900  I would specially call upon my young friends e...  2021-01-01 04:51:10
#
#      vadersenti_compound     senti
# 0                 0.9246  positive
# 1                 0.8402  positive
# 2                 0.7269  positive
# 3                 0.7003  positive
# 4                 0.4588  positive
# ..                   ...       ...
# 896              -0.0164  negative
# 897               0.9337  positive
# 898               0.3818  positive
# 899               0.8074  positive
# 900               0.8625  positive
#
# [901 rows x 4 columns]

# %%
df2=df2.drop(['vadersenti_compound','date'],axis=1)

# %%
df2
# Out:
#                                                   text     senti
# 0    Happy to have met you and the brilliant Nambi ...  positive
# 1    The strength and faith of the people of the co...  positive
# 2    A new format several interesting questions on ...  positive
# 3    My best wishes to President Alberto Fernández ...  positive
# 4    Reviewed the COVID and vaccination related sit...  positive
# ..                                                 ...       ...
# 896  Starting today the work of  light house projec...  negative
# 897  Birthday wishes to Manipur’s CM Shri   Ji His ...  positive
# 898  Leveraging latest technologies to ensure Housi...  positive
# 899  The The Light House Projects LHPs will showcas...  positive
# 900  I would specially call upon my young friends e...  positive
#
# [901 rows x 2 columns]

# %%
def get_tweets_Sentiment(sentiment_score):
    if sentiment_score == 'negative':
        return '-1'
    elif sentiment_score == 'neutral':
        return '0'
    else:
        return '1'
    
df2['Sentiment_Score'] = df2['senti'].apply(get_tweets_Sentiment)

# %%
df2
# Out:
#                                                   text     senti  \
# 0    Happy to have met you and the brilliant Nambi ...  positive
# 1    The strength and faith of the people of the co...  positive
# 2    A new format several interesting questions on ...  positive
# 3    My best wishes to President Alberto Fernández ...  positive
# 4    Reviewed the COVID and vaccination related sit...  positive
# ..                                                 ...       ...
# 896  Starting today the work of  light house projec...  negative
# 897  Birthday wishes to Manipur’s CM Shri   Ji His ...  positive
# 898  Leveraging latest technologies to ensure Housi...  positive
# 899  The The Light House Projects LHPs will showcas...  positive
# 900  I would specially call upon my young friends e...  positive
#
#     Sentiment_Score
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ..              ...
# 896              -1
# 897               1
# 898               1
# 899               1
# 900               1
#
# [901 rows x 3 columns]

# %%
df2.to_csv('tweets_modi_timelinetweetrecentFINAL.csv' , sep=',')

# %%
df3 = pd.read_csv('tweets_modi_timelinetweetrecentFINAL.csv')

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in df3.text:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 1400, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8,7), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
